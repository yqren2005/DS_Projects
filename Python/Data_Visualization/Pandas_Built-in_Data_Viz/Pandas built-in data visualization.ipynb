# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
df1 = pd.read_csv('df1', index_col=0)
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1.A.hist(edgecolor='r')

# %%
df1.A.plot(kind='hist', bins=50, edgecolor='black')

# %%
df2.plot(kind='area', alpha=0.6)

# %%
df2.plot.box()

# %%
df2.shape
# Out:
# (10, 4)

# %%
df2.plot.bar(stacked=True)

# %%
df1.plot.line(x=df1.index, y='B', figsize=(16, 4), lw=1)

# %%
df1.shape
# Out:
# (1000, 4)

# %%
sns.set_style('ticks')
df1.plot.scatter(x='A', y='B', c='C', figsize=(10, 8), cmap='rainbow', s=150, alpha=0.8, marker='*')

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['A', 'B'])
df.head()
# Out:
#           A         B
# 0 -0.052194  0.412863
# 1  0.997405 -0.354050
# 2  2.903311 -1.032917
# 3 -0.121722  0.780271
# 4 -0.305013 -1.485516

# %%
df.plot.hexbin('A', 'B', figsize=(10, 8), gridsize=25, cmap='coolwarm')

# %%
df2.plot.kde()
